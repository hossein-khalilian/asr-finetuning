# %%
import nemo.collections.asr as nemo_asr
asr_model = nemo_asr.models.EncDecHybridRNNTCTCBPEModel.from_pretrained(model_name="nvidia/stt_fa_fastconformer_hybrid_large")
# Out:
# [NeMo I 2025-07-16 07:01:49 nemo_logging:393] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2025-07-16 07:01:50 nemo_logging:405] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: dummy
#     sample_rate: 16000
#     batch_size: 1
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     max_duration: 10
#     min_duration: 0.5
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: fully_randomized
#     bucketing_batch_size: null
#     use_lhotse: true
#     lhotse:
#       shar_path: /data_artifacts/data/shar/train
#       batch_duration: 1200
#       quadratic_duration: 15
#       num_buckets: 10
#       num_cuts_for_bins_estimate: 10000
#       buffer_size: 10000
#       shuffle_buffer_size: 10000
#
# [NeMo W 2025-07-16 07:01:50 nemo_logging:405] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /data_artifacts/data/nemo/dev_decoded_exprunner.json
#     sample_rate: 16000
#     batch_size: 512
#     shuffle: false
#     use_start_end_token: false
#     num_workers: 8
#     pin_memory: true
#
# [NeMo W 2025-07-16 07:01:50 nemo_logging:405] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: /data_artifacts/data/nemo/test_decoded_exprunner.json
#     sample_rate: 16000
#     batch_size: 512
#     shuffle: false
#     use_start_end_token: false
#     num_workers: 8
#     pin_memory: true
# [NeMo I 2025-07-16 07:01:50 nemo_logging:393] PADDING: 0
# [NeMo I 2025-07-16 07:01:51 nemo_logging:393] Using RNNT Loss : warprnnt_numba
#     Loss warprnnt_numba_kwargs: {'fastemit_lambda': 0.0, 'clamp': -1.0}
# [NeMo I 2025-07-16 07:01:51 nemo_logging:393] Using RNNT Loss : warprnnt_numba
#     Loss warprnnt_numba_kwargs: {'fastemit_lambda': 0.0, 'clamp': -1.0}
# [NeMo W 2025-07-16 07:01:51 nemo_logging:405] No conditional node support for Cuda.
#     Cuda graphs with while loops are disabled, decoding speed will be slower
#     Reason: cannot import name '__version__' from 'cuda' (unknown location)
# [NeMo I 2025-07-16 07:01:51 nemo_logging:393] Using RNNT Loss : warprnnt_numba
#     Loss warprnnt_numba_kwargs: {'fastemit_lambda': 0.0, 'clamp': -1.0}
# [NeMo W 2025-07-16 07:01:51 nemo_logging:405] No conditional node support for Cuda.
#     Cuda graphs with while loops are disabled, decoding speed will be slower
#     Reason: cannot import name '__version__' from 'cuda' (unknown location)
# [NeMo I 2025-07-16 07:01:52 nemo_logging:393] Model EncDecHybridRNNTCTCBPEModel was successfully restored from /home/jovyan/.cache/huggingface/hub/models--nvidia--stt_fa_fastconformer_hybrid_large/snapshots/249cf5bf70dda7220a60ddeeecff2f6aad8e1784/stt_fa_fastconformer_hybrid_large.nemo.

# %%
asr_model.to_config_dict()
# Out:
# {'sample_rate': 16000, 'compute_eval_loss': False, 'log_prediction': True, 'skip_nan_grad': False, 'model_defaults': {'enc_hidden': 512, 'pred_hidden': 640, 'joint_hidden': 640}, 'train_ds': {'manifest_filepath': 'dummy', 'sample_rate': 16000, 'batch_size': 1, 'shuffle': True, 'num_workers': 8, 'pin_memory': True, 'max_duration': 10, 'min_duration': 0.5, 'is_tarred': False, 'tarred_audio_filepaths': None, 'shuffle_n': 2048, 'bucketing_strategy': 'fully_randomized', 'bucketing_batch_size': None, 'use_lhotse': True, 'lhotse': {'shar_path': '/data_artifacts/data/shar/train', 'batch_duration': 1200, 'quadratic_duration': 15, 'num_buckets': 10, 'num_cuts_for_bins_estimate': 10000, 'buffer_size': 10000, 'shuffle_buffer_size': 10000}}, 'validation_ds': {'manifest_filepath': '/data_artifacts/data/nemo/dev_decoded_exprunner.json', 'sample_rate': 16000, 'batch_size': 512, 'shuffle': False, 'use_start_end_token': False, 'num_workers': 8, 'pin_memory': True}, 'test_ds': {'manifest_filepath': '/data_artifacts/data/nemo/test_decoded_exprunner.json', 'sample_rate': 16000, 'batch_size': 512, 'shuffle': False, 'use_start_end_token': False, 'num_workers': 8, 'pin_memory': True}, 'tokenizer': {'dir': '/data_artifacts/tokenizers/tokenizer_spe_bpe_v1024_max_4', 'type': 'bpe', 'model_path': 'nemo:ef26492f516f4b45af531c82920f005e_tokenizer.model', 'vocab_path': 'nemo:e1598203ebbe4e509b503ef4b4852e79_vocab.txt', 'spe_tokenizer_vocab': 'nemo:d733fbc360ae4b0f97db1d89886f1e4a_tokenizer.vocab'}, 'preprocessor': {'_target_': 'nemo.collections.asr.modules.AudioToMelSpectrogramPreprocessor', 'sample_rate': 16000, 'normalize': 'per_feature', 'window_size': 0.025, 'window_stride': 0.01, 'window': 'hann', 'features': 80, 'n_fft': 512, 'frame_splicing': 1, 'dither': 1e-05, 'pad_to': 0}, 'spec_augment': {'_target_': 'nemo.collections.asr.modules.SpectrogramAugmentation', 'freq_masks': 2, 'time_masks': 10, 'freq_width': 27, 'time_width': 0.05}, 'encoder': {'_target_': 'nemo.collections.asr.modules.ConformerEncoder', 'feat_in': 80, 'feat_out': -1, 'n_layers': 17, 'd_model': 512, 'subsampling': 'dw_striding', 'subsampling_factor': 8, 'subsampling_conv_channels': 256, 'causal_downsampling': False, 'reduction': None, 'reduction_position': None, 'reduction_factor': 1, 'ff_expansion_factor': 4, 'self_attention_model': 'rel_pos', 'n_heads': 8, 'att_context_size': [-1, -1], 'att_context_style': 'regular', 'xscaling': False, 'untie_biases': True, 'pos_emb_max_len': 5000, 'conv_kernel_size': 9, 'conv_norm_type': 'batch_norm', 'conv_context_size': None, 'dropout': 0.1, 'dropout_pre_encoder': 0.1, 'dropout_emb': 0.0, 'dropout_att': 0.1, 'stochastic_depth_drop_prob': 0.0, 'stochastic_depth_mode': 'linear', 'stochastic_depth_start_layer': 1}, 'decoder': {'_target_': 'nemo.collections.asr.modules.RNNTDecoder', 'normalization_mode': None, 'random_state_sampling': False, 'blank_as_pad': True, 'prednet': {'pred_hidden': 640, 'pred_rnn_layers': 1, 't_max': None, 'dropout': 0.2}, 'vocab_size': 1024}, 'joint': {'_target_': 'nemo.collections.asr.modules.RNNTJoint', 'log_softmax': None, 'preserve_memory': False, 'fuse_loss_wer': True, 'fused_batch_size': 4, 'jointnet': {'joint_hidden': 640, 'activation': 'relu', 'dropout': 0.2, 'encoder_hidden': 512, 'pred_hidden': 640}, 'num_classes': 1024, 'vocabulary': ['<unk>', '▁ب', '▁م', '▁ا', '▁ک', '▁د', 'ار', 'ست', 'ان', '▁ر', '▁می', '▁ت', 'ای', '▁ن', '▁خ', 'ین', '▁و', '▁ه', '▁ش', 'ید', 'ند', '▁به', 'رد', '▁س', '▁آ', '▁چ', 'ود', '▁پ', 'ون', '▁را', '▁با', '▁من', 'اد', '▁این', '▁ی', '▁در', 'یم', '▁از', '▁بر', '▁کن', '▁است', 'ام', '▁خو', '▁که', 'ال', 'اه', '▁تو', '▁دار', '▁گ', '▁ج', 'ور', 'یر', '▁ف', '▁ز', '▁رو', '▁ح', 'شت', 'فت', 'لی', '▁هم', 'یا', '▁او', '▁ق', '▁کرد', '▁ع', '▁یک', 'ما', 'ده', 'می', 'های', 'اب', '▁بود', 'ها', 'ری', '▁دو', 'لا', 'رو', 'را', 'جا', 'سی', '▁آن', '▁ل', 'کن', '▁ما', '▁کار', 'تر', '▁هست', '▁ص', '▁چی', '▁چه', 'زی', '▁بی', '▁مو', 'تی', '▁خود', '▁ام', 'شه', '▁شما', 'رم', 'اشت', 'وی', '▁کنم', '▁نمی', '▁تا', '▁شد', 'نگ', 'اس ...

# %%
asr_model.to_config_dict()
# Out:
# {'sample_rate': 16000, 'compute_eval_loss': False, 'log_prediction': True, 'skip_nan_grad': False, 'model_defaults': {'enc_hidden': 512, 'pred_hidden': 640, 'joint_hidden': 640}, 'train_ds': {'manifest_filepath': 'dummy', 'sample_rate': 16000, 'batch_size': 1, 'shuffle': True, 'num_workers': 8, 'pin_memory': True, 'max_duration': 10, 'min_duration': 0.5, 'is_tarred': False, 'tarred_audio_filepaths': None, 'shuffle_n': 2048, 'bucketing_strategy': 'fully_randomized', 'bucketing_batch_size': None, 'use_lhotse': True, 'lhotse': {'shar_path': '/data_artifacts/data/shar/train', 'batch_duration': 1200, 'quadratic_duration': 15, 'num_buckets': 10, 'num_cuts_for_bins_estimate': 10000, 'buffer_size': 10000, 'shuffle_buffer_size': 10000}}, 'validation_ds': {'manifest_filepath': '/data_artifacts/data/nemo/dev_decoded_exprunner.json', 'sample_rate': 16000, 'batch_size': 512, 'shuffle': False, 'use_start_end_token': False, 'num_workers': 8, 'pin_memory': True}, 'test_ds': {'manifest_filepath': '/data_artifacts/data/nemo/test_decoded_exprunner.json', 'sample_rate': 16000, 'batch_size': 512, 'shuffle': False, 'use_start_end_token': False, 'num_workers': 8, 'pin_memory': True}, 'tokenizer': {'dir': '/data_artifacts/tokenizers/tokenizer_spe_bpe_v1024_max_4', 'type': 'bpe', 'model_path': 'nemo:ef26492f516f4b45af531c82920f005e_tokenizer.model', 'vocab_path': 'nemo:e1598203ebbe4e509b503ef4b4852e79_vocab.txt', 'spe_tokenizer_vocab': 'nemo:d733fbc360ae4b0f97db1d89886f1e4a_tokenizer.vocab'}, 'preprocessor': {'_target_': 'nemo.collections.asr.modules.AudioToMelSpectrogramPreprocessor', 'sample_rate': 16000, 'normalize': 'per_feature', 'window_size': 0.025, 'window_stride': 0.01, 'window': 'hann', 'features': 80, 'n_fft': 512, 'frame_splicing': 1, 'dither': 1e-05, 'pad_to': 0}, 'spec_augment': {'_target_': 'nemo.collections.asr.modules.SpectrogramAugmentation', 'freq_masks': 2, 'time_masks': 10, 'freq_width': 27, 'time_width': 0.05}, 'encoder': {'_target_': 'nemo.collections.asr.modules.ConformerEncoder', 'feat_in': 80, 'feat_out': -1, 'n_layers': 17, 'd_model': 512, 'subsampling': 'dw_striding', 'subsampling_factor': 8, 'subsampling_conv_channels': 256, 'causal_downsampling': False, 'reduction': None, 'reduction_position': None, 'reduction_factor': 1, 'ff_expansion_factor': 4, 'self_attention_model': 'rel_pos', 'n_heads': 8, 'att_context_size': [-1, -1], 'att_context_style': 'regular', 'xscaling': False, 'untie_biases': True, 'pos_emb_max_len': 5000, 'conv_kernel_size': 9, 'conv_norm_type': 'batch_norm', 'conv_context_size': None, 'dropout': 0.1, 'dropout_pre_encoder': 0.1, 'dropout_emb': 0.0, 'dropout_att': 0.1, 'stochastic_depth_drop_prob': 0.0, 'stochastic_depth_mode': 'linear', 'stochastic_depth_start_layer': 1}, 'decoder': {'_target_': 'nemo.collections.asr.modules.RNNTDecoder', 'normalization_mode': None, 'random_state_sampling': False, 'blank_as_pad': True, 'prednet': {'pred_hidden': 640, 'pred_rnn_layers': 1, 't_max': None, 'dropout': 0.2}, 'vocab_size': 1024}, 'joint': {'_target_': 'nemo.collections.asr.modules.RNNTJoint', 'log_softmax': None, 'preserve_memory': False, 'fuse_loss_wer': True, 'fused_batch_size': 4, 'jointnet': {'joint_hidden': 640, 'activation': 'relu', 'dropout': 0.2, 'encoder_hidden': 512, 'pred_hidden': 640}, 'num_classes': 1024, 'vocabulary': ['<unk>', '▁ب', '▁م', '▁ا', '▁ک', '▁د', 'ار', 'ست', 'ان', '▁ر', '▁می', '▁ت', 'ای', '▁ن', '▁خ', 'ین', '▁و', '▁ه', '▁ش', 'ید', 'ند', '▁به', 'رد', '▁س', '▁آ', '▁چ', 'ود', '▁پ', 'ون', '▁را', '▁با', '▁من', 'اد', '▁این', '▁ی', '▁در', 'یم', '▁از', '▁بر', '▁کن', '▁است', 'ام', '▁خو', '▁که', 'ال', 'اه', '▁تو', '▁دار', '▁گ', '▁ج', 'ور', 'یر', '▁ف', '▁ز', '▁رو', '▁ح', 'شت', 'فت', 'لی', '▁هم', 'یا', '▁او', '▁ق', '▁کرد', '▁ع', '▁یک', 'ما', 'ده', 'می', 'های', 'اب', '▁بود', 'ها', 'ری', '▁دو', 'لا', 'رو', 'را', 'جا', 'سی', '▁آن', '▁ل', 'کن', '▁ما', '▁کار', 'تر', '▁هست', '▁ص', '▁چی', '▁چه', 'زی', '▁بی', '▁مو', 'تی', '▁خود', '▁ام', 'شه', '▁شما', 'رم', 'اشت', 'وی', '▁کنم', '▁نمی', '▁تا', '▁شد', 'نگ', 'اس ...
